# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import os
location = 'C:\\Users\\Danita\\Desktop\\sensorCityData\\06Oct\\2016-10-24\\06Oct-28-AU-1-20161006_100000.wav.1.hdf5'
soundData = h5py.File(location , 'r')
print soundData.keys()
energyVal = soundData.get('energy')
print energyVal
energyArray= np.array(energyVal)
avg=0
count = 0
#print energyArray[1]
#for val in range(len(energyArray)-12,len(energyArray)-6):
for val in range(0,12):
#    print energyArray[val]
    avgofRow = np.average(energyArray[val])
#    print avgofRow
    if np.isfinite(avgofRow):
        count= count +1
        avg = np.average(energyArray[val])+avg
#        print np.average(energyArray[val])

#print avg/count

f=plt.figure(figsize=(16,6))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray, interpolation='nearest',aspect='auto')
plt.show()
# Out:
# [u'energy', u'noise', u'pulse', u'tone']
# <HDF5 dataset "energy": shape (22, 1798), type "<f4">

# %%
f=plt.figure(figsize=(16,6))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray[0:15], interpolation='nearest',aspect='auto')
plt.show()
print energyArray[0:15].shape,energyArray[0:15].size
# Out:
# (15L, 1798L) 26970

# %%
import numpy as np
import os
location = '/home/danita/data/GIT_cc14a7a227c856aee6e0b541b97a77aabb8d3307-2016-10-05-15-14/ptne/hdf5/2016-10-05/04oct1-201-AU-1-20161004_100000.wav.1.hdf5'
soundData = h5py.File(location , 'r')
print soundData.keys()
energyVal1 = soundData.get('tone')
print energyVal1
energyArray1= np.array(energyVal1)
avg1=0
count1 = 0
#print energyArray[1]
for val in range(len(energyArray)-12,len(energyArray)-6):
    avgofRow1 = np.average(energyArray1[val])
#    print avgofRow
    if np.isfinite(avgofRow1):
        count1= count1 +1
        avg1 = np.average(energyArray1[val])+avg1
        print np.average(energyArray1[val])

print avg1/count1

# %%
f=plt.figure(figsize=(16,5))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray1, interpolation='nearest',aspect='auto')
plt.show()

# %%
import numpy as np
import os
location = '/home/danita/data/GIT_cc14a7a227c856aee6e0b541b97a77aabb8d3307-2016-10-05-18-41/ptne/hdf5/2016-10-05/02octp1-201-AU-1-20161002_100000.wav.1.hdf5'
soundData = h5py.File(location , 'r')
print soundData.keys()
energyVal2 = soundData.get('tone')
print energyVal2
energyArray2= np.array(energyVal2)
avg2=0
count2 = 0
#print energyArray[1]
for val in range(len(energyArray2)-12,len(energyArray2)-6):
    avgofRow2 = np.average(energyArray2[val])
#    print avgofRow
    if np.isfinite(avgofRow2):
        count2= count2 +1
        avg2 = np.average(energyArray2[val])+avg2
        print np.average(energyArray2[val])

print avg2/count2

# %%
f=plt.figure(figsize=(16,5))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray1, interpolation='nearest',aspect='auto')
plt.show()

# %% [markdown]
# # 202 Sensor

# %% [markdown]
# 04 october

# %%
import numpy as np
import os
location = '/home/danita/data/GIT_cc14a7a227c856aee6e0b541b97a77aabb8d3307-2016-10-07-12-04/ptne/hdf5/2016-10-07/02oct-202.wav.1.hdf5'
soundData = h5py.File(location , 'r')
print soundData.keys()
energyVal2 = soundData.get('tone')
print energyVal2
energyArray2= np.array(energyVal2)
avg2=0
count2 = 0
#print energyArray[1]
for val in range(len(energyArray2)-12,len(energyArray2)-6):
    avgofRow2 = np.average(energyArray2[val])
#    print avgofRow
    if np.isfinite(avgofRow2):
        count2= count2 +1
        avg2 = np.average(energyArray2[val])+avg2
        print np.average(energyArray2[val])

print avg2/count2
# Out:
# [u'energy', u'noise', u'pulse', u'tone']
# <HDF5 dataset "tone": shape (22, 17253), type "<f4">
# 32.3852
# 32.4837
# 28.4871
# 31.1903
# 31.7879
# 31.6124
# 31.3244193395

# %%
f=plt.figure(figsize=(16,5))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray2, interpolation='nearest',aspect='auto')
plt.show()

# %% [markdown]
# 04 OCT

# %%
import numpy as np
import os
location = '/home/danita/data/GIT_cc14a7a227c856aee6e0b541b97a77aabb8d3307-2016-10-07-12-19/ptne/hdf5/2016-10-07/04oct202.wav.1.hdf5'
soundData = h5py.File(location , 'r')
print soundData.keys()
energyVal2 = soundData.get('tone')
print energyVal2
energyArray2= np.array(energyVal2)
avg2=0
count2 = 0
#print energyArray[1]
for val in range(len(energyArray2)-12,len(energyArray2)-6):
    avgofRow2 = np.average(energyArray2[val])
#    print avgofRow
    if np.isfinite(avgofRow2):
        count2= count2 +1
        avg2 = np.average(energyArray2[val])+avg2
        print np.average(energyArray2[val])

print avg2/count2
# Out:
# [u'energy', u'noise', u'pulse', u'tone']
# <HDF5 dataset "tone": shape (22, 17253), type "<f4">
# 28.6244
# 30.0643
# 29.9132
# 27.2006
# 27.73
# 29.509
# 28.8402570089

# %%
f=plt.figure(figsize=(16,5))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray2, interpolation='nearest',aspect='auto')
plt.show()

# %% [markdown]
# Siren 03 Oct

# %%
import numpy as np
import os
location = '/home/danita/data/soundFiles/alarm againagain-202-AU-1-20161003_100000.wav.1.hdf5'
soundData = h5py.File(location , 'r')
print soundData.keys()
energyVal2 = soundData.get('tone')
print energyVal2
energyArray2= np.array(energyVal2)
avg2=0
count2 = 0
#print energyArray[1]
for val in range(len(energyArray2)-12,len(energyArray2)-6):
    avgofRow2 = np.average(energyArray2[val])
#    print avgofRow
    if np.isfinite(avgofRow2):
        count2= count2 +1
        avg2 = np.average(energyArray2[val])+avg2
        print np.average(energyArray2[val])

print avg2/count2
# Out:
# [u'energy', u'noise', u'pulse', u'tone']
# <HDF5 dataset "tone": shape (22, 1803), type "<f4">
# 47.2543
# 47.3859
# 49.6521
# 50.7489
# 49.352
# 50.0456
# 49.0731455485

# %%
f=plt.figure(figsize=(16,5))
ax = f.add_subplot(1,1,1)
ax.imshow(energyArray2, interpolation='nearest',aspect='auto')
plt.show()
